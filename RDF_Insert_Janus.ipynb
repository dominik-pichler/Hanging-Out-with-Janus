# %%
from rdflib import Graph
from gremlin_python.driver import client


rdf_graph = Graph()
rdf_graph.parse("data/Testdataset.rdf", format="turtle")

gremlin_client = client.Client('ws://localhost:8182/gremlin', 'g')

# For visual inspection! 
for subj, pred, obj in rdf_graph:
    print(f"Subj: {subj}, Pred: {pred}, Obj: {obj}")
# Out:
# Subj: ex_addr:21, Pred: http://localhost/hasStreet, Obj: Statthalterplatz c/o Kiosk am Bahnhof
# Subj: ex_addr:32, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:52, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:38, Pred: http://localhost/hasStreet, Obj: Fuhlsbüttler Straße 387
# Subj: ex_comp:63, Pred: http://localhost/hasAddress, Obj: ex_addr:58
# Subj: ex_addr:35, Pred: http://localhost/hasStreet, Obj: Caffamacherreihe 7
# Subj: ex_comp:31, Pred: http://localhost/hasName, Obj: FB trust GmbH
# Subj: ex_addr:6, Pred: http://localhost/hasStreet, Obj: Lierenfelder Straße 42
# Subj: ex_addr:55, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:34, Pred: http://localhost/hasStreet, Obj: Luftfrachthof-Geb.
# Subj: ex_comp:70, Pred: http://localhost/hasAddress, Obj: ex_addr:63
# Subj: ex_addr:32, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:98, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:46, Pred: http://localhost/hasAddress, Obj: Rosenstraße 2, 20095 Hamburg.
# Subj: ex_addr:33, Pred: http://localhost/hasPLZ, Obj: 40472
# Subj: ex_comp:7, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:62, Pred: http://localhost/hasStreet, Obj: Raboisen 38
# Subj: ex_comp:59, Pred: http://localhost/hasName, Obj: AGARBA Grundstücks-Vermietungsgesellschaft mbH
# Subj: ex_addr:60, Pred: http://localhost/hasAddress, Obj: Mattentwiete 1, 20457 Hamburg.
# Subj: ex_addr:44, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:57, Pred: http://localhost/hasPLZ, Obj: 28195
# Subj: ex_comp:62, Pred: http://localhost/hasAddress, Obj: ex_addr:57
# Subj: ex_addr:79, Pred: http://localhost/hasStreet, Obj: Krefelder Straße 85
# Subj: ex_addr:43, Pred: http://localhost/hasAddress, Obj: Neumühlen 13, 22763 Hamburg.
# Subj: ex_comp:15, Pred: http://localhost/hasAddress, Obj: ex_addr:13
# Subj: ex_comp:42, Pred: http://localhost/hasAddress, Obj: ex_addr:40
# Subj: ex_comp:78, Pred: http://localhost/hasName, Obj: Mutabor Brandspaces GmbH
# Subj: ex_addr:3, Pred: http://localhost/hasPLZ, Obj: 28195
# Subj: ex_addr:70, Pred: http://localhost/hasAddress, Obj: Barsbütteler Str.
# Subj: ex_comp:39, Pred: http://localhost/hasAddress, Obj: ex_addr:37
# Subj: ex_addr:77, Pred: http://localhost/hasPLZ, Obj: 21129
# Subj: ex_addr:40, Pred: http://localhost/hasPLZ, Obj: 20357
# Subj: ex_comp:37, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:49, Pred: http://localhost/hasAddress, Obj: ex_addr:47
# Subj: ex_comp:79, Pred: http://localhost/hasName, Obj: Gebäudereinigung Wolff GmbH
# Subj: ex_comp:64, Pred: http://localhost/hasFNR, Obj: R1101_HRA19353
# Subj: ex_addr:6, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_comp:26, Pred: http://localhost/hasName, Obj: Dr. Gottfried Neuhaus Treuhand GmbH
# Subj: ex_comp:23, Pred: http://localhost/hasName, Obj: HCG Hanse Convenience GmbH
# Subj: ex_comp:88, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:61, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:22, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:2, Pred: http://localhost/hasName, Obj: BLUECHILLED Verwaltungs GmbH
# Subj: ex_comp:50, Pred: http://localhost/hasName, Obj: Auerbach Trading GmbH
# Subj: ex_comp:58, Pred: http://localhost/hasFNR, Obj: K1101R_HRB1787
# Subj: ex_comp:30, Pred: http://localhost/hasFNR, Obj: R1101_HRB36406
# Subj: ex_comp:61, Pred: http://localhost/hasName, Obj: Victoria Lebensversicherung Aktiengesellschaft
# Subj: ex_comp:76, Pred: http://localhost/hasName, Obj: AVASPA Bremen Vermietungsgesellschaft mbH
# Subj: ex_comp:84, Pred: http://localhost/hasAddress, Obj: ex_addr:76
# Subj: ex_comp:31, Pred: http://localhost/hasAddress, Obj: ex_addr:29
# Subj: ex_addr:26, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:15, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:25, Pred: http://localhost/hasStreet, Obj: Rhenaniastraße 16
# Subj: ex_addr:81, Pred: http://localhost/hasStreet, Obj: Contrescarpe 8 c
# Subj: ex_addr:39, Pred: http://localhost/hasAddress, Obj: Bei den St. Pauli Landungsbrücken 3, 20359 Hamburg.
# Subj: ex_addr:64, Pred: http://localhost/hasPLZ, Obj: c/o
# Subj: ex_addr:72, Pred: http://localhost/hasPLZ, Obj: 40476
# Subj: ex_comp:14, Pred: http://localhost/hasFNR, Obj: R1101_HRB63476
# Subj: ex_comp:6, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:73, Pred: http://localhost/hasAddress, Obj: ex_addr:66
# Subj: ex_addr:28, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:52, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:18, Pred: http://localhost/hasAddress, Obj: ex_addr:16
# Subj: ex_comp:37, Pred: http://localhost/hasFNR, Obj: K1101R_HRA104534
# Subj: ex_comp:86, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:8, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:14, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_addr:30, Pred: http://localhost/hasStreet, Obj: Goldbekplatz 1
# Subj: ex_comp:45, Pred: http://localhost/hasFNR, Obj: K1101R_HRB75822
# Subj: ex_addr:22, Pred: http://localhost/hasAddress, Obj: Überseeallee 1, 20457 Hamburg.
# Subj: ex_addr:17, Pred: http://localhost/hasPLZ, Obj: 22765
# Subj: ex_addr:18, Pred: http://localhost/hasStreet, Obj: Am Buschhäuschen 19
# Subj: ex_addr:26, Pred: http://localhost/hasPLZ, Obj: 22525
# Subj: ex_addr:37, Pred: http://localhost/hasPLZ, Obj: 22529
# Subj: ex_comp:26, Pred: http://localhost/hasFNR, Obj: K1101R_HRB75540
# Subj: ex_comp:97, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:92, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:92, Pred: http://localhost/hasFNR, Obj: R1101_HRB1703
# Subj: ex_addr:56, Pred: http://localhost/hasStreet, Obj: Heidenkampsweg 99
# Subj: ex_addr:23, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:58, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:3, Pred: http://localhost/hasStreet, Obj: Langenstraße 2-4
# Subj: ex_comp:74, Pred: http://localhost/hasAddress, Obj: ex_addr:67
# Subj: ex_comp:11, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:25, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:55, Pred: http://localhost/hasName, Obj: Ojooo Vo GmbH
# Subj: ex_comp:81, Pred: http://localhost/hasAddress, Obj: ex_addr:73
# Subj: ex_addr:14, Pred: http://localhost/hasAddress, Obj: Mündelheimer Weg 40, 40472 Düsseldorf.
# Subj: ex_addr:29, Pred: http://localhost/hasAddress, Obj: Leipoldstieg 5, 22605 Hamburg.
# Subj: ex_comp:35, Pred: http://localhost/hasFNR, Obj: R1101_HRB66409
# Subj: ex_comp:66, Pred: http://localhost/hasFNR, Obj: K1101R_HRB131199
# Subj: ex_comp:81, Pred: rdf:type, Obj: ex:Company
# Subj: ex_empl:624, Pred: http://localhost/endDate, Obj: 2013-04-08
# Subj: ex_comp:49, Pred: http://localhost/hasName, Obj: ZAEVERS GmbH
# Subj: ex_comp:61, Pred: http://localhost/hasAddress, Obj: ex_addr:5
# Subj: ex_comp:67, Pred: http://localhost/hasAddress, Obj: ex_addr:62
# Subj: ex_addr:23, Pred: http://localhost/hasAddress, Obj: Mönckebergstraße 13, 20095 Hamburg.
# Subj: ex_comp:6, Pred: http://localhost/hasFNR, Obj: R1101_HRB562
# Subj: ex_addr:21, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:100, Pred: http://localhost/hasName, Obj: Harburg-Freudenberger Maschinenbau GmbH
# Subj: ex_comp:2, Pred: http://localhost/hasAddress, Obj: ex_addr:2
# Subj: ex_addr:73, Pred: http://localhost/hasAddress, Obj: Neuländer Kamp 1a, 21079 Hamburg.
# Subj: ex_comp:76, Pred: http://localhost/hasAddress, Obj: ex_addr:69
# Subj: ex_addr:69, Pred: http://localhost/hasPLZ, Obj: 22549
# Subj: ex_comp:42, Pred: http://localhost/hasFNR, Obj: K1101R_HRB136461
# Subj: ex_addr:76, Pred: http://localhost/hasPLZ, Obj: 20354
# Subj: ex_addr:25, Pred: http://localhost/hasPLZ, Obj: 40789
# Subj: ex_comp:12, Pred: http://localhost/hasFNR, Obj: K1101R_HRA93667
# Subj: ex_addr:20, Pred: http://localhost/hasAddress, Obj: Cremon 3, 20457 Hamburg.
# Subj: ex_addr:85, Pred: http://localhost/hasPLZ, Obj: 28203
# Subj: ex_addr:14, Pred: http://localhost/hasStreet, Obj: Mündelheimer Weg 40
# Subj: ex_comp:34, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:82, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:36, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:84, Pred: http://localhost/hasName, Obj: BLVÈ UG (haftungsbeschränkt)
# Subj: ex_comp:45, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:37, Pred: http://localhost/hasAddress, Obj: Troplowitzstraße 20, 22529 Hamburg.
# Subj: ex_comp:44, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:38, Pred: http://localhost/hasAddress, Obj: Fuhlsbüttler Straße 387, 22309 Hamburg.
# Subj: ex_comp:47, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:44, Pred: http://localhost/hasFNR, Obj: K1101R_HRB107269
# Subj: ex_comp:25, Pred: http://localhost/hasName, Obj: Comfort Hamburg Gesellschaft für Geschäftsflächen und Unternehmensvermittlung mbH
# Subj: ex_addr:49, Pred: http://localhost/hasPLZ, Obj: 40476
# Subj: ex_comp:7, Pred: http://localhost/hasAddress, Obj: ex_addr:7
# Subj: ex_comp:83, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:76, Pred: http://localhost/hasAddress, Obj: Große Bleichen 31, 20354 Hamburg.
# Subj: ex_addr:13, Pred: http://localhost/hasAddress, Obj: Gasstraße 4 c, 22761 Hamburg.
# Subj: ex_addr:78, Pred: http://localhost/hasAddress, Obj: Worthdamm 13-27, 20457 Hamburg.
# Subj: ex_addr:54, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:57, Pred: http://localhost/hasFNR, Obj: K1101R_HRB98062
# Subj: ex_comp:60, Pred: http://localhost/hasAddress, Obj: ex_addr:56
# Subj: ex_addr:74, Pred: http://localhost/hasStreet, Obj: Dominikanerstraße 24
# Subj: ex_comp:81, Pred: http://localhost/hasName, Obj: Eurofins GSC Germany GmbH
# Subj: ex_addr:17, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:55, Pred: http://localhost/hasFNR, Obj: K1101R_HRB124404
# Subj: ex_addr:42, Pred: http://localhost/hasStreet, Obj: Spielbudenplatz 27-28
# Subj: ex_addr:44, Pred: http://localhost/hasPLZ, Obj: 20539
# Subj: ex_addr:6, Pred: http://localhost/hasAddress, Obj: Lierenfelder Straße 42, 40231 Düsseldorf.
# Subj: ex_addr:16, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_comp:67, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:53, Pred: http://localhost/hasName, Obj: Verwaltung MS "HAMMONIA TOSCANA" GmbH
# Subj: ex_comp:56, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:65, Pred: http://localhost/hasFNR, Obj: K1101R_HRB89103
# Subj: ex_comp:1, Pred: http://localhost/hasName, Obj: olly UG (haftungsbeschränkt)
# Subj: ex_addr:45, Pred: http://localhost/hasAddress, Obj: Ludwig-Erhard-Straße 22, 20459 Hamburg.
# Subj: ex_comp:70, Pred: http://localhost/hasName, Obj: Wünsche Services GmbH
# Subj: ex_addr:41, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:56, Pred: http://localhost/hasPLZ, Obj: 20097
# Subj: ex_comp:77, Pred: http://localhost/hasAddress, Obj: ex_addr:70
# Subj: ex_comp:19, Pred: http://localhost/hasName, Obj: "ad fontes" Solartechnik GmbH
# Subj: ex_addr:41, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:73, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:60, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:23, Pred: http://localhost/hasPLZ, Obj: 20095
# Subj: ex_addr:67, Pred: http://localhost/hasStreet, Obj: Martinistraße 58
# Subj: ex_addr:79, Pred: http://localhost/hasAddress, Obj: Krefelder Straße 85, 40549 Düsseldorf.
# Subj: ex_addr:72, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:86, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:66, Pred: http://localhost/hasAddress, Obj: ex_addr:61
# Subj: ex_comp:2, Pred: http://localhost/hasFNR, Obj: R1101_HRB81092
# Subj: ex_comp:27, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:10, Pred: http://localhost/hasName, Obj: POX Media Verwaltungs GmbH
# Subj: ex_addr:60, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:28, Pred: http://localhost/hasName, Obj: Panasonic Europe Ltd. Zweigniederlassung Deutschland Hamburg Office
# Subj: ex_addr:59, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_comp:42, Pred: http://localhost/hasName, Obj: Factor Design Verwaltungs GmbH
# Subj: ex_comp:35, Pred: http://localhost/hasAddress, Obj: ex_addr:33
# Subj: ex_addr:60, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:52, Pred: http://localhost/hasName, Obj: [m]SCIENCE GmbH
# Subj: ex_comp:2, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:78, Pred: http://localhost/hasAddress, Obj: ex_addr:7
# Subj: ex_comp:93, Pred: http://localhost/hasAddress, Obj: ex_addr:83
# Subj: ex_addr:32, Pred: http://localhost/hasAddress, Obj: Barner Straße 45, 22765 Hamburg.
# Subj: ex_comp:26, Pred: http://localhost/hasAddress, Obj: ex_addr:24
# Subj: ex_comp:72, Pred: http://localhost/hasFNR, Obj: H1101_H1101_HRB16653
# Subj: ex_addr:62, Pred: http://localhost/hasAddress, Obj: Raboisen 38, 20095 Hamburg.
# Subj: ex_addr:8, Pred: http://localhost/hasStreet, Obj: Hans-Henny-Jahnn-Weg 41-45
# Subj: ex_comp:26, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:22, Pred: http://localhost/hasFNR, Obj: K1101R_HRB103933
# Subj: ex_addr:17, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:15, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:10, Pred: http://localhost/hasAddress, Obj: Große Elbstraße 38, 22767 Hamburg.
# Subj: ex_addr:88, Pred: http://localhost/hasStreet, Obj: Mittelweg 31
# Subj: ex_comp:20, Pred: http://localhost/hasAddress, Obj: ex_addr:18
# Subj: ex_comp:61, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:50, Pred: http://localhost/hasFNR, Obj: R1101_HRB62678
# Subj: ex_comp:59, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:18, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:54, Pred: http://localhost/hasName, Obj: C. Gathmann Computer-System-Beratung GmbH
# Subj: ex_comp:40, Pred: http://localhost/hasName, Obj: Verwaltung Projektgesellschaft Marco Polo Tower GmbH
# Subj: ex_comp:69, Pred: http://localhost/hasFNR, Obj: K1101R_HRB117991
# Subj: ex_comp:27, Pred: http://localhost/hasName, Obj: Monheimer Biermanufactur GmbH
# Subj: ex_addr:26, Pred: http://localhost/hasAddress, Obj: Winsbergring 15, 22525 Hamburg.
# Subj: ex_comp:47, Pred: http://localhost/hasFNR, Obj: K1101R_HRB58718
# Subj: ex_comp:59, Pred: http://localhost/hasAddress, Obj: ex_addr:9
# Subj: ex_addr:39, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:82, Pred: http://localhost/hasStreet, Obj: Balcke-Dürr-Allee 3
# Subj: ex_addr:33, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_addr:84, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:8, Pred: http://localhost/hasName, Obj: AWS Personalmarketing GmbH
# Subj: ex_comp:95, Pred: http://localhost/hasAddress, Obj: ex_addr:85
# Subj: ex_addr:82, Pred: http://localhost/hasCity, Obj: Ratingen.
# Subj: ex_addr:68, Pred: http://localhost/hasStreet, Obj: Gerresheimer Straße 37
# Subj: ex_comp:1, Pred: http://localhost/hasFNR, Obj: K1101R_HRB150148
# Subj: ex_comp:80, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:65, Pred: http://localhost/hasName, Obj: Verwaltung "MS Sophie" Schifffahrtsgesellschaft mbH
# Subj: ex_addr:24, Pred: http://localhost/hasAddress, Obj: Gustav-Mahler-Platz 1, 20354 Hamburg.
# Subj: ex_addr:39, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:97, Pred: http://localhost/hasFNR, Obj: R1101_HRB38642
# Subj: ex_addr:53, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:74, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:24, Pred: http://localhost/hasPLZ, Obj: 20354
# Subj: ex_addr:18, Pred: http://localhost/hasAddress, Obj: Am Buschhäuschen 19,, 42115 Wuppertal.
# Subj: ex_addr:38, Pred: http://localhost/hasPLZ, Obj: 22309
# Subj: ex_addr:65, Pred: http://localhost/hasCity, Obj: Bremen
# Subj: ex_comp:48, Pred: http://localhost/hasFNR, Obj: K1101R_HRB5604
# Subj: ex_comp:89, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:82, Pred: http://localhost/hasPLZ, Obj: 40882
# Subj: ex_comp:16, Pred: http://localhost/hasFNR, Obj: R1101_HRB61492
# Subj: ex_comp:44, Pred: http://localhost/hasName, Obj: Schmidts Tivoli Gastspiel GmbH
# Subj: ex_addr:85, Pred: http://localhost/hasCity, Obj: Bremen
# Subj: ex_comp:58, Pred: http://localhost/hasAddress, Obj: ex_addr:55
# Subj: ex_comp:69, Pred: http://localhost/hasAddress, Obj: ex_addr:50
# Subj: ex_comp:38, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:38, Pred: http://localhost/hasName, Obj: KidINVEST GmbH
# Subj: ex_comp:33, Pred: http://localhost/hasFNR, Obj: K1101R_HRB105553
# Subj: ex_addr:49, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:54, Pred: http://localhost/hasAddress, Obj: ex_addr:51
# Subj: ex_addr:43, Pred: http://localhost/hasStreet, Obj: Neumühlen 13
# Subj: ex_addr:19, Pred: http://localhost/hasAddress, Obj: Neuer Steinweg 26, 20459 Hamburg.
# Subj: ex_comp:18, Pred: http://localhost/hasName, Obj: SIEBTE PAXAS Treuhand- und Beteiligungsgesellschaft mbH
# Subj: ex_comp:86, Pred: http://localhost/hasName, Obj: Sasol Wax GmbH
# Subj: ex_comp:72, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:55, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:7, Pred: http://localhost/hasStreet, Obj: Königstraße 28
# Subj: ex_addr:57, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:83, Pred: http://localhost/hasAddress, Obj: Jägerhofstraße 10, 40479 Düsseldorf.
# Subj: ex_addr:85, Pred: http://localhost/hasStreet, Obj: Ostertorsteinweg 85
# Subj: ex_addr:59, Pred: http://localhost/hasStreet, Obj: Carl-Theodor-Straße 6
# Subj: ex_comp:40, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:3, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:90, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:31, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:77, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:30, Pred: http://localhost/hasPLZ, Obj: 22303
# Subj: ex_addr:36, Pred: http://localhost/hasAddress, Obj: Benrather Straße 18-20, 40213 Düsseldorf.
# Subj: ex_comp:84, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:16, Pred: http://localhost/hasName, Obj: ElectronicPartner Handel SE
# Subj: ex_addr:87, Pred: http://localhost/hasPLZ, Obj: 40212
# Subj: ex_addr:31, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:36, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:90, Pred: http://localhost/hasAddress, Obj: ex_addr:9
# Subj: ex_addr:8, Pred: http://localhost/hasAddress, Obj: Hans-Henny-Jahnn-Weg 41-45, 22085 Hamburg.
# Subj: ex_addr:81, Pred: http://localhost/hasPLZ, Obj: 28203
# Subj: ex_comp:41, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:56, Pred: http://localhost/hasFNR, Obj: R1101_HRB77984
# Subj: ex_addr:NA, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:44, Pred: http://localhost/hasAddress, Obj: ex_addr:42
# Subj: ex_comp:47, Pred: http://localhost/hasAddress, Obj: ex_addr:45
# Subj: ex_addr:22, Pred: http://localhost/hasPLZ, Obj: 20457
# Subj: ex_addr:83, Pred: http://localhost/hasStreet, Obj: Jägerhofstraße 10
# Subj: ex_comp:11, Pred: http://localhost/hasName, Obj: HB-DIGITAL GmbH
# Subj: ex_comp:71, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:53, Pred: http://localhost/hasStreet, Obj: Marienstraße 33
# Subj: ex_comp:46, Pred: http://localhost/hasName, Obj: AMB Trade GmbH
# Subj: ex_comp:24, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:36, Pred: http://localhost/hasFNR, Obj: K1101R_HRB28646
# Subj: ex_addr:44, Pred: http://localhost/hasStreet, Obj: Mühlenhagen 130
# Subj: ex_comp:63, Pred: http://localhost/hasName, Obj: Amber Shipping UG (haftungsbeschränkt) & Co. KG
# Subj: ex_comp:90, Pred: http://localhost/hasName, Obj: WEHR BULKCARRIERS GmbH & Co KG
# Subj: ex_addr:89, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:48, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:17, Pred: http://localhost/hasFNR, Obj: K1101R_HRB133214
# Subj: ex_addr:80, Pred: http://localhost/hasPLZ, Obj: 22337
# Subj: ex_addr:28, Pred: http://localhost/hasAddress, Obj: Schiessstraße 60, 40549 Düsseldorf.
# Subj: ex_comp:9, Pred: http://localhost/hasFNR, Obj: K1101R_PR190
# Subj: ex_addr:15, Pred: http://localhost/hasStreet, Obj: Jacobsenweg 7
# Subj: ex_comp:36, Pred: http://localhost/hasAddress, Obj: ex_addr:34
# Subj: ex_addr:25, Pred: http://localhost/hasAddress, Obj: Rhenaniastraße 16, 40789 Monheim am Rhein.
# Subj: ex_addr:52, Pred: http://localhost/hasPLZ, Obj: 20457
# Subj: ex_comp:29, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:4, Pred: http://localhost/hasFNR, Obj: R1101_HRB45109
# Subj: ex_comp:50, Pred: http://localhost/hasAddress, Obj: ex_addr:48
# Subj: ex_comp:25, Pred: http://localhost/hasFNR, Obj: K1101R_HRB80939
# Subj: ex_comp:34, Pred: http://localhost/hasAddress, Obj: ex_addr:32
# Subj: ex_comp:33, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:20, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:51, Pred: http://localhost/hasName, Obj: Poertzgen GmbH Unternehmensberatung
# Subj: ex_comp:53, Pred: http://localhost/hasAddress, Obj: ex_addr:50
# Subj: ex_comp:28, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:20, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:77, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:39, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:27, Pred: http://localhost/hasFNR, Obj: R1101_HRB74015
# Subj: ex_comp:30, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:64, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:73, Pred: http://localhost/hasPLZ, Obj: 21079
# Subj: ex_addr:27, Pred: http://localhost/hasPLZ, Obj: 22767
# Subj: ex_comp:94, Pred: http://localhost/hasAddress, Obj: ex_addr:84
# Subj: ex_addr:34, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:96, Pred: http://localhost/hasName, Obj: Dewigo (Dealing with goods) UG (haftungsbeschränkt)
# Subj: ex_addr:75, Pred: http://localhost/hasAddress, Obj: Alte Bottroper Str.
# Subj: ex_addr:76, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:3, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:19, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:79, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:86, Pred: http://localhost/hasStreet, Obj: Borner Stieg 32
# Subj: ex_comp:35, Pred: http://localhost/hasName, Obj: JANT Express-Logistik UG (haftungsbeschränkt)
# Subj: ex_comp:15, Pred: http://localhost/hasName, Obj: S-KON Sales Kontor Hamburg GmbH
# Subj: ex_addr:12, Pred: http://localhost/hasAddress, Obj: Kaiserswerther Str.
# Subj: ex_addr:11, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:81, Pred: http://localhost/hasCity, Obj: Bremen
# Subj: ex_addr:7, Pred: http://localhost/hasPLZ, Obj: 22767
# Subj: ex_addr:64, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:16, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:69, Pred: http://localhost/hasName, Obj: MS "Favourisation" Verwaltung GmbH
# Subj: ex_comp:71, Pred: http://localhost/hasAddress, Obj: ex_addr:64
# Subj: ex_addr:30, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:21, Pred: http://localhost/hasFNR, Obj: K1101R_HRB151714
# Subj: ex_comp:20, Pred: http://localhost/hasFNR, Obj: R1101_HRB63845
# Subj: ex_addr:87, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:37, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:52, Pred: http://localhost/hasFNR, Obj: R1101_HRB39820
# Subj: ex_addr:90, Pred: http://localhost/hasStreet, Obj: Seevestraße 1
# Subj: ex_empl:624, Pred: rdf:type, Obj: ex:Employment
# Subj: ex_addr:71, Pred: http://localhost/hasStreet, Obj: Saseler Bogen 3
# Subj: ex_comp:5, Pred: http://localhost/hasFNR, Obj: R1101_HRB37996
# Subj: ex_addr:78, Pred: http://localhost/hasPLZ, Obj: 20457
# Subj: ex_comp:8, Pred: http://localhost/hasAddress, Obj: ex_addr:8
# Subj: ex_addr:45, Pred: http://localhost/hasStreet, Obj: Ludwig-Erhard-Straße 22
# Subj: ex_comp:29, Pred: http://localhost/hasAddress, Obj: ex_addr:27
# Subj: ex_addr:37, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:77, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:13, Pred: http://localhost/hasStreet, Obj: Gasstraße 4 c
# Subj: ex_comp:96, Pred: http://localhost/hasFNR, Obj: K1101R_HRB142783
# Subj: ex_comp:3, Pred: http://localhost/hasAddress, Obj: ex_addr:3
# Subj: ex_comp:94, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:65, Pred: http://localhost/hasPLZ, Obj: 28755
# Subj: ex_comp:97, Pred: http://localhost/hasName, Obj: NPC HOTELENTWICKLUNGS U. - MANAGEMENT GmbH
# Subj: ex_comp:40, Pred: http://localhost/hasFNR, Obj: K1101R_HRB106228
# Subj: ex_comp:9, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:25, Pred: http://localhost/hasCity, Obj: Monheim
# Subj: ex_addr:4, Pred: http://localhost/hasStreet, Obj: Hans-Sachs-Straße 11
# Subj: ex_addr:68, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:94, Pred: http://localhost/hasName, Obj: Hartungstraße 12 Verwaltungsgesellschaft mbH
# Subj: ex_addr:82, Pred: http://localhost/hasAddress, Obj: Balcke-Dürr-Allee 3, 40882 Ratingen.
# Subj: ex_addr:55, Pred: http://localhost/hasStreet, Obj: Unnastr.
# Subj: ex_addr:13, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:83, Pred: http://localhost/hasFNR, Obj: R1101_HRB78963
# Subj: ex_comp:39, Pred: http://localhost/hasName, Obj: NXP Semiconductors Germany GmbH
# Subj: ex_comp:50, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:15, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:89, Pred: http://localhost/hasCity, Obj: Bremen.
# Subj: ex_addr:87, Pred: http://localhost/hasStreet, Obj: Königsallee 92a
# Subj: ex_comp:34, Pred: http://localhost/hasFNR, Obj: K1101R_HRB117903
# Subj: ex_comp:43, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:73, Pred: http://localhost/hasFNR, Obj: R1101_HRB62068
# Subj: ex_comp:88, Pred: http://localhost/hasAddress, Obj: ex_addr:16
# Subj: ex_addr:76, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:42, Pred: http://localhost/hasPLZ, Obj: 20359
# Subj: ex_comp:77, Pred: http://localhost/hasName, Obj: TOL Time of Luxury GmbH
# Subj: ex_comp:100, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:60, Pred: http://localhost/hasFNR, Obj: K1101R_HRB124341
# Subj: ex_comp:74, Pred: http://localhost/hasName, Obj: Atlantik Hafenbetriebe Geuther & Schnitger GmbH & Co. KG
# Subj: ex_comp:94, Pred: http://localhost/hasFNR, Obj: K1101R_HRB103106
# Subj: ex_addr:31, Pred: http://localhost/hasAddress, Obj: Neuer Wall 54, 20354 Hamburg.
# Subj: ex_addr:86, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:90, Pred: http://localhost/hasPLZ, Obj: 21079
# Subj: ex_addr:44, Pred: http://localhost/hasAddress, Obj: Mühlenhagen 130, 20539 Hamburg.
# Subj: ex_comp:12, Pred: http://localhost/hasName, Obj: Neunte Grundstücksverwaltung AHG-Beteiligungs- und Handelsgesellschaft mbH & Co. KG
# Subj: ex_addr:8, Pred: http://localhost/hasPLZ, Obj: 22085
# Subj: ex_addr:79, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_comp:22, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:23, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:10, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:52, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:68, Pred: http://localhost/hasAddress, Obj: Gerresheimer Straße 37, 40211 Düsseldorf.
# Subj: ex_addr:10, Pred: http://localhost/hasPLZ, Obj: 22767
# Subj: ex_comp:32, Pred: http://localhost/hasName, Obj: Can Koi Ibiza GmbH & Co. KG
# Subj: ex_comp:65, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:21, Pred: http://localhost/hasName, Obj: Yücebudak IT & Vertrieb UG (haftungsbeschränkt)
# Subj: ex_addr:27, Pred: http://localhost/hasAddress, Obj: Palmaille 120, 22767 Hamburg.
# Subj: ex_addr:12, Pred: http://localhost/hasStreet, Obj: Kaiserswerther Str.
# Subj: ex_addr:15, Pred: http://localhost/hasPLZ, Obj: 22525
# Subj: ex_addr:31, Pred: http://localhost/hasStreet, Obj: Neuer Wall 54
# Subj: ex_addr:22, Pred: http://localhost/hasStreet, Obj: Überseeallee 1
# Subj: ex_comp:64, Pred: http://localhost/hasName, Obj: REDEVCO Logistics Güdderath GmbH & Co. OHG
# Subj: ex_addr:27, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:34, Pred: http://localhost/hasName, Obj: W247 web app systems UG (haftungsbeschränkt)
# Subj: ex_comp:98, Pred: http://localhost/hasFNR, Obj: K1101R_HRB123809
# Subj: ex_comp:48, Pred: http://localhost/hasAddress, Obj: ex_addr:46
# Subj: ex_addr:45, Pred: http://localhost/hasPLZ, Obj: 20459
# Subj: ex_addr:80, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:39, Pred: http://localhost/hasStreet, Obj: Bei den St. Pauli Landungsbrücken 3
# Subj: ex_comp:5, Pred: http://localhost/hasAddress, Obj: ex_addr:5
# Subj: ex_addr:60, Pred: http://localhost/hasPLZ, Obj: 20457
# Subj: ex_addr:18, Pred: http://localhost/hasPLZ, Obj: 42115
# Subj: ex_addr:61, Pred: http://localhost/hasPLZ, Obj: 21073
# Subj: ex_comp:73, Pred: http://localhost/hasName, Obj: Achte display system GmbH
# Subj: ex_comp:59, Pred: http://localhost/hasFNR, Obj: R1101_HRB37943
# Subj: ex_addr:58, Pred: http://localhost/hasStreet, Obj: Teerhof 59
# Subj: ex_comp:29, Pred: http://localhost/hasName, Obj: "Renta Reederei" GmbH
# Subj: ex_addr:2, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:13, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:82, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:95, Pred: http://localhost/hasFNR, Obj: H1101_H1101_HRA25576
# Subj: ex_empl:624, Pred: http://localhost/employs, Obj: ex_name:443
# Subj: ex_comp:23, Pred: http://localhost/hasAddress, Obj: ex_addr:21
# Subj: ex_comp:17, Pred: http://localhost/hasAddress, Obj: ex_addr:15
# Subj: ex_addr:35, Pred: http://localhost/hasPLZ, Obj: 20355
# Subj: ex_comp:69, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:6, Pred: http://localhost/hasPLZ, Obj: 40231
# Subj: ex_comp:13, Pred: http://localhost/hasAddress, Obj: ex_addr:9
# Subj: ex_addr:54, Pred: http://localhost/hasPLZ, Obj: 20457
# Subj: ex_comp:75, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:93, Pred: http://localhost/hasFNR, Obj: R1101_HRB25617
# Subj: ex_addr:70, Pred: http://localhost/hasStreet, Obj: Barsbütteler Str.
# Subj: ex_addr:53, Pred: http://localhost/hasAddress, Obj: Marienstraße 33, 40210 Düsseldorf.
# Subj: ex_comp:22, Pred: http://localhost/hasAddress, Obj: ex_addr:20
# Subj: ex_addr:24, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:53, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:33, Pred: http://localhost/hasName, Obj: Feedback Vermögensberatungs- und Vermittlungsgesellschaft mbH
# Subj: ex_comp:42, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:62, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:50, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:17, Pred: http://localhost/hasAddress, Obj: Gaußstraße 158, 22765 Hamburg.
# Subj: ex_addr:89, Pred: http://localhost/hasAddress, Obj: Zur Westpier 40, 28755 Bremen.
# Subj: ex_addr:79, Pred: http://localhost/hasPLZ, Obj: 40549
# Subj: ex_comp:46, Pred: http://localhost/hasFNR, Obj: K1101R_HRB102365
# Subj: ex_addr:11, Pred: http://localhost/hasAddress, Obj: Wahlerstraße 16, 40472 Düsseldorf.
# Subj: ex_addr:75, Pred: http://localhost/hasStreet, Obj: Alte Bottroper Str.
# Subj: ex_comp:39, Pred: http://localhost/hasFNR, Obj: K1101R_HRB84865
# Subj: ex_comp:46, Pred: http://localhost/hasAddress, Obj: ex_addr:44
# Subj: ex_addr:77, Pred: http://localhost/hasAddress, Obj: Finkenwerder Norderdeich 133, 21129 Hamburg.
# Subj: ex_addr:27, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:13, Pred: http://localhost/hasPLZ, Obj: 22761
# Subj: ex_comp:100, Pred: http://localhost/hasAddress, Obj: ex_addr:90
# Subj: ex_addr:40, Pred: http://localhost/hasAddress, Obj: Schulterblatt 58, 20357 Hamburg.
# Subj: ex_addr:41, Pred: http://localhost/hasStreet, Obj: Friedensallee 271
# Subj: ex_addr:59, Pred: http://localhost/hasPLZ, Obj: 40213
# Subj: ex_addr:28, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_addr:19, Pred: http://localhost/hasPLZ, Obj: 20459
# Subj: ex_comp:80, Pred: http://localhost/hasName, Obj: He:Lee EXPO - Messe : Consulting : Project Management Verwaltungs GmbH
# Subj: ex_addr:50, Pred: http://localhost/hasAddress, Obj: Neumühlen 9, 22763 Hamburg.
# Subj: ex_addr:41, Pred: http://localhost/hasPLZ, Obj: 22763
# Subj: ex_addr:5, Pred: http://localhost/hasAddress, Obj: ERGO-Platz 1, 40477 Düsseldorf.
# Subj: ex_addr:65, Pred: http://localhost/hasAddress, Obj: Löpelborg 8, 28755 Bremen
# Subj: ex_addr:56, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:7, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:48, Pred: http://localhost/hasAddress, Obj: Ronsdorfer Str.
# Subj: ex_addr:34, Pred: http://localhost/hasAddress, Obj: Luftfrachthof-Geb.
# Subj: ex_addr:83, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:86, Pred: http://localhost/hasFNR, Obj: K1101R_HRB73963
# Subj: ex_addr:43, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:10, Pred: http://localhost/hasFNR, Obj: K1101R_HRB136672
# Subj: ex_addr:15, Pred: http://localhost/hasAddress, Obj: Jacobsenweg 7, 22525 Hamburg.
# Subj: ex_addr:56, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:36, Pred: http://localhost/hasName, Obj: SEABRIDGE Transport GmbH
# Subj: ex_comp:49, Pred: http://localhost/hasFNR, Obj: K1101R_HRB141956
# Subj: ex_addr:88, Pred: http://localhost/hasPLZ, Obj: 20148
# Subj: ex_comp:9, Pred: http://localhost/hasAddress, Obj: ex_addr:9
# Subj: ex_addr:28, Pred: http://localhost/hasPLZ, Obj: 40549
# Subj: ex_addr:36, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_addr:74, Pred: http://localhost/hasPLZ, Obj: 40545
# Subj: ex_comp:47, Pred: http://localhost/hasName, Obj: Verwaltung ZEABORN Ship Management GmbH
# Subj: ex_addr:33, Pred: http://localhost/hasStreet, Obj: Am Schüttenhof 16
# Subj: ex_comp:19, Pred: http://localhost/hasAddress, Obj: ex_addr:17
# Subj: ex_comp:27, Pred: http://localhost/hasAddress, Obj: ex_addr:25
# Subj: ex_comp:43, Pred: http://localhost/hasAddress, Obj: ex_addr:41
# Subj: ex_addr:84, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:24, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:54, Pred: http://localhost/hasAddress, Obj: Mattentwiete 6, 20457 Hamburg.
# Subj: ex_addr:62, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:63, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:33, Pred: http://localhost/hasAddress, Obj: Am Schüttenhof 16, 40472 Düsseldorf.
# Subj: ex_addr:6, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:90, Pred: http://localhost/hasAddress, Obj: Seevestraße 1, 21079 Hamburg.
# Subj: ex_comp:20, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:72, Pred: http://localhost/hasAddress, Obj: Spichernstraße 34, 40476 Düsseldorf.
# Subj: ex_addr:5, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:12, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:14, Pred: http://localhost/hasAddress, Obj: ex_addr:12
# Subj: ex_addr:1, Pred: http://localhost/hasAddress, Obj: Waidmannstraße 1, 22769 Hamburg.
# Subj: ex_comp:17, Pred: http://localhost/hasName, Obj: Stadtküche GmbH
# Subj: ex_comp:4, Pred: http://localhost/hasName, Obj: Albert Barufe GmbH
# Subj: ex_addr:66, Pred: http://localhost/hasStreet, Obj: Neustraße 45
# Subj: ex_name:1, Pred: rdf:type, Obj: ex:Name
# Subj: ex_addr:4, Pred: http://localhost/hasCity, Obj: Hilden.
# Subj: ex_addr:21, Pred: http://localhost/hasPLZ, Obj: 22605
# Subj: ex_addr:32, Pred: http://localhost/hasStreet, Obj: Barner Straße 45
# Subj: ex_addr:4, Pred: http://localhost/hasAddress, Obj: Hans-Sachs-Straße 11, 40721 Hilden.
# Subj: ex_addr:50, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:41, Pred: http://localhost/hasAddress, Obj: ex_addr:39
# Subj: ex_addr:11, Pred: http://localhost/hasPLZ, Obj: 40472
# Subj: ex_addr:35, Pred: http://localhost/hasAddress, Obj: Caffamacherreihe 7, 20355 Hamburg.
# Subj: ex_empl:624, Pred: http://localhost/worksAt, Obj: ex_comp:74
# Subj: ex_addr:12, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:37, Pred: http://localhost/hasStreet, Obj: Troplowitzstraße 20
# Subj: ex_comp:38, Pred: http://localhost/hasFNR, Obj: R1101_HRB72204
# Subj: ex_comp:98, Pred: http://localhost/hasName, Obj: TRACOA GmbH
# Subj: ex_comp:14, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:74, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:32, Pred: http://localhost/hasAddress, Obj: ex_addr:30
# Subj: ex_comp:82, Pred: http://localhost/hasAddress, Obj: ex_addr:74
# Subj: ex_addr:88, Pred: http://localhost/hasAddress, Obj: Mittelweg 31, 20148 Hamburg.
# Subj: ex_comp:10, Pred: http://localhost/hasAddress, Obj: ex_addr:10
# Subj: ex_comp:62, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:62, Pred: http://localhost/hasPLZ, Obj: 20095
# Subj: ex_addr:85, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:19, Pred: http://localhost/hasStreet, Obj: Neuer Steinweg 26
# Subj: ex_addr:84, Pred: http://localhost/hasStreet, Obj: Hartungstraße 12
# Subj: ex_comp:51, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:58, Pred: http://localhost/hasName, Obj: Beiersdorf Aktiengesellschaft
# Subj: ex_comp:75, Pred: http://localhost/hasFNR, Obj: R1101_HRB79984
# Subj: ex_addr:76, Pred: http://localhost/hasStreet, Obj: Große Bleichen 31
# Subj: ex_comp:85, Pred: http://localhost/hasAddress, Obj: ex_addr:77
# Subj: ex_comp:45, Pred: http://localhost/hasAddress, Obj: ex_addr:43
# Subj: ex_addr:43, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:66, Pred: http://localhost/hasCity, Obj: Hilden.
# Subj: ex_comp:57, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:59, Pred: http://localhost/hasAddress, Obj: Carl-Theodor-Straße 6, 40213 Düsseldorf.
# Subj: ex_comp:99, Pred: http://localhost/hasAddress, Obj: ex_addr:89
# Subj: ex_comp:41, Pred: http://localhost/hasName, Obj: Eckelmann Umwelt Holding GmbH
# Subj: ex_addr:2, Pred: http://localhost/hasAddress, Obj: Oststr.
# Subj: ex_addr:36, Pred: http://localhost/hasStreet, Obj: Benrather Straße 18-20
# Subj: ex_addr:10, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:64, Pred: http://localhost/hasCity, Obj: Matzen
# Subj: ex_comp:82, Pred: http://localhost/hasName, Obj: EQUINOX Investment GmbH
# Subj: ex_comp:51, Pred: http://localhost/hasAddress, Obj: ex_addr:9
# Subj: ex_comp:99, Pred: http://localhost/hasName, Obj: Muehlhan Deutschland GmbH
# Subj: ex_addr:27, Pred: http://localhost/hasStreet, Obj: Palmaille 120
# Subj: ex_addr:73, Pred: http://localhost/hasStreet, Obj: Neuländer Kamp 1a
# Subj: ex_comp:21, Pred: http://localhost/hasAddress, Obj: ex_addr:19
# Subj: ex_comp:38, Pred: http://localhost/hasAddress, Obj: ex_addr:36
# Subj: ex_addr:58, Pred: http://localhost/hasPLZ, Obj: 28199
# Subj: ex_addr:49, Pred: http://localhost/hasAddress, Obj: Derendorfer Allee 4, 40476 Düsseldorf.
# Subj: ex_addr:10, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:40, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:45, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:67, Pred: http://localhost/hasAddress, Obj: Martinistraße 58, 28195 Bremen
# Subj: ex_addr:67, Pred: http://localhost/hasCity, Obj: Bremen
# Subj: ex_addr:36, Pred: http://localhost/hasPLZ, Obj: 40213
# Subj: ex_addr:66, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:87, Pred: http://localhost/hasAddress, Obj: ex_addr:79
# Subj: ex_addr:45, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:19, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:86, Pred: http://localhost/hasPLZ, Obj: 22417
# Subj: ex_addr:71, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:38, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:52, Pred: http://localhost/hasAddress, Obj: Am Kaiserkai 69, 20457 Hamburg.
# Subj: ex_comp:37, Pred: http://localhost/hasAddress, Obj: ex_addr:35
# Subj: ex_addr:57, Pred: http://localhost/hasCity, Obj: Bremen
# Subj: ex_comp:48, Pred: http://localhost/hasName, Obj: DZ HYP AG
# Subj: ex_empl:624, Pred: http://localhost/position, Obj: Prokurist
# Subj: ex_addr:58, Pred: http://localhost/hasAddress, Obj: Teerhof 59, 28199 Bremen..
# Subj: ex_comp:81, Pred: http://localhost/hasFNR, Obj: K1101R_HRB126642
# Subj: ex_addr:80, Pred: http://localhost/hasStreet, Obj: Am Stein 46
# Subj: ex_addr:84, Pred: http://localhost/hasPLZ, Obj: 20146
# Subj: ex_addr:87, Pred: http://localhost/hasAddress, Obj: Königsallee 92a, 40212 Düsseldorf.
# Subj: ex_addr:65, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:1, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:7, Pred: http://localhost/hasFNR, Obj: K1101R_HRB82839
# Subj: ex_comp:88, Pred: http://localhost/hasFNR, Obj: R1101_HRB54999
# Subj: ex_addr:21, Pred: http://localhost/hasAddress, Obj: Statthalterplatz c/o Kiosk am Bahnhof, 22605 Hamburg.
# Subj: ex_comp:89, Pred: http://localhost/hasFNR, Obj: K1101R_HRB134246
# Subj: ex_addr:30, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:89, Pred: http://localhost/hasName, Obj: GENIGO GmbH
# Subj: ex_comp:24, Pred: http://localhost/hasName, Obj: FAP Beteiligungsgesellschaft mbH
# Subj: ex_comp:100, Pred: http://localhost/hasFNR, Obj: K1101R_HRB64651
# Subj: ex_addr:77, Pred: http://localhost/hasStreet, Obj: Finkenwerder Norderdeich 133
# Subj: ex_comp:89, Pred: http://localhost/hasAddress, Obj: ex_addr:80
# Subj: ex_comp:12, Pred: http://localhost/hasAddress, Obj: ex_addr:9
# Subj: ex_addr:14, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:70, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:16, Pred: http://localhost/hasPLZ, Obj: 40215
# Subj: ex_comp:78, Pred: http://localhost/hasFNR, Obj: K1101R_HRB95193
# Subj: ex_comp:68, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:72, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_addr:1, Pred: http://localhost/hasStreet, Obj: Waidmannstraße 1
# Subj: ex_addr:74, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_comp:9, Pred: http://localhost/hasName, Obj: Rembert Rechtsanwälte Rembert Müller Putzier + Partner eingetragene Partnerschaft mit beschränkter Berufshaftung
# Subj: ex_addr:89, Pred: http://localhost/hasStreet, Obj: Zur Westpier 40
# Subj: ex_comp:68, Pred: http://localhost/hasFNR, Obj: R1101_VR10715
# Subj: ex_comp:74, Pred: http://localhost/hasFNR, Obj: H1101_H1101_HRA17696
# Subj: ex_addr:3, Pred: http://localhost/hasAddress, Obj: Langenstraße 2-4, 28195 Bremen.
# Subj: ex_addr:66, Pred: http://localhost/hasPLZ, Obj: 40721
# Subj: ex_addr:47, Pred: http://localhost/hasStreet, Obj: Katharinenstr.
# Subj: ex_addr:29, Pred: http://localhost/hasPLZ, Obj: 22605
# Subj: ex_addr:47, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:30, Pred: http://localhost/hasAddress, Obj: Goldbekplatz 1, 22303 Hamburg.
# Subj: ex_comp:60, Pred: http://localhost/hasName, Obj: Baumarkt Max Bahr Praktiker Einkaufs GmbH
# Subj: ex_addr:75, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:11, Pred: http://localhost/hasStreet, Obj: Wahlerstraße 16
# Subj: ex_comp:72, Pred: http://localhost/hasAddress, Obj: ex_addr:65
# Subj: ex_addr:46, Pred: http://localhost/hasStreet, Obj: Rosenstraße 2
# Subj: ex_addr:40, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:69, Pred: http://localhost/hasStreet, Obj: Harderweg 1
# Subj: ex_addr:13, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:3, Pred: http://localhost/hasName, Obj: Mittelständische Beteiligungsgesellschaft Bremen mbH
# Subj: ex_comp:78, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:6, Pred: http://localhost/hasAddress, Obj: ex_addr:6
# Subj: ex_addr:51, Pred: http://localhost/hasAddress, Obj: Orleansstr.
# Subj: ex_comp:90, Pred: http://localhost/hasFNR, Obj: K1101R_HRA96011
# Subj: ex_addr:1, Pred: http://localhost/hasPLZ, Obj: 22769
# Subj: ex_comp:52, Pred: http://localhost/hasAddress, Obj: ex_addr:49
# Subj: ex_addr:48, Pred: http://localhost/hasStreet, Obj: Ronsdorfer Str.
# Subj: ex_addr:57, Pred: http://localhost/hasStreet, Obj: Tiefer 15
# Subj: ex_addr:67, Pred: http://localhost/hasPLZ, Obj: 28195
# Subj: ex_addr:49, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_comp:88, Pred: http://localhost/hasName, Obj: VIERTE Fonds-Beteiligungsgesellschaft mbH
# Subj: ex_addr:83, Pred: http://localhost/hasPLZ, Obj: 40479
# Subj: ex_comp:32, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:71, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:29, Pred: http://localhost/hasStreet, Obj: Leipoldstieg 5
# Subj: ex_comp:22, Pred: http://localhost/hasName, Obj: Verwaltung NORDCAPITAL Schiffsportfolio 4 GmbH
# Subj: ex_comp:33, Pred: http://localhost/hasAddress, Obj: ex_addr:31
# Subj: ex_comp:23, Pred: http://localhost/hasFNR, Obj: K1101R_HRB119632
# Subj: ex_comp:93, Pred: http://localhost/hasName, Obj: Lampe Asset Management GmbH
# Subj: ex_addr:72, Pred: http://localhost/hasStreet, Obj: Spichernstraße 34
# Subj: ex_comp:85, Pred: http://localhost/hasFNR, Obj: K1101R_HRB129147
# Subj: ex_comp:97, Pred: http://localhost/hasAddress, Obj: ex_addr:87
# Subj: ex_addr:58, Pred: http://localhost/hasCity, Obj: Bremen..
# Subj: ex_comp:57, Pred: http://localhost/hasAddress, Obj: ex_addr:54
# Subj: ex_addr:61, Pred: http://localhost/hasAddress, Obj: Bremer Straße 103a, 21073 Hamburg.
# Subj: ex_addr:78, Pred: http://localhost/hasStreet, Obj: Worthdamm 13-27
# Subj: ex_addr:41, Pred: http://localhost/hasAddress, Obj: Friedensallee 271, 22763 Hamburg.
# Subj: ex_addr:79, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:53, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_comp:11, Pred: http://localhost/hasAddress, Obj: ex_addr:11
# Subj: ex_comp:11, Pred: http://localhost/hasFNR, Obj: R1101_HRB69455
# Subj: ex_addr:3, Pred: http://localhost/hasCity, Obj: Bremen.
# Subj: ex_addr:51, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:52, Pred: http://localhost/hasStreet, Obj: Am Kaiserkai 69
# Subj: ex_addr:69, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:80, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:54, Pred: http://localhost/hasStreet, Obj: Mattentwiete 6
# Subj: ex_comp:24, Pred: http://localhost/hasFNR, Obj: K1101R_HRB131125
# Subj: ex_comp:65, Pred: http://localhost/hasAddress, Obj: ex_addr:60
# Subj: ex_addr:17, Pred: http://localhost/hasStreet, Obj: Gaußstraße 158
# Subj: ex_comp:66, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:59, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:17, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:18, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:16, Pred: http://localhost/hasStreet, Obj: Königsallee 106
# Subj: ex_addr:28, Pred: http://localhost/hasStreet, Obj: Schiessstraße 60
# Subj: ex_addr:69, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:96, Pred: http://localhost/hasAddress, Obj: ex_addr:86
# Subj: ex_comp:91, Pred: http://localhost/hasAddress, Obj: ex_addr:81
# Subj: ex_addr:63, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:54, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:68, Pred: http://localhost/hasAddress, Obj: ex_addr:9
# Subj: ex_addr:39, Pred: http://localhost/hasPLZ, Obj: 20359
# Subj: ex_addr:63, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:16, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:63, Pred: http://localhost/hasAddress, Obj: Domstraße 19, 20095 Hamburg.
# Subj: ex_comp:31, Pred: http://localhost/hasFNR, Obj: K1101R_HRB143087
# Subj: ex_comp:68, Pred: http://localhost/hasName, Obj: Närrische Frauen Himmelgeist e.V.
# Subj: ex_comp:37, Pred: http://localhost/hasName, Obj: Schiffsfonds Ownership Tonnage VII GmbH & Co. KG
# Subj: ex_addr:46, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:19, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:78, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:64, Pred: http://localhost/hasStreet, Obj: Neuer Wall 55
# Subj: ex_addr:26, Pred: http://localhost/hasStreet, Obj: Winsbergring 15
# Subj: ex_addr:2, Pred: http://localhost/hasStreet, Obj: Oststr.
# Subj: ex_comp:64, Pred: http://localhost/hasAddress, Obj: ex_addr:59
# Subj: ex_comp:25, Pred: http://localhost/hasAddress, Obj: ex_addr:23
# Subj: ex_comp:56, Pred: http://localhost/hasName, Obj: Alessio Analytics UG (haftungsbeschränkt)
# Subj: ex_addr:5, Pred: http://localhost/hasStreet, Obj: ERGO-Platz 1
# Subj: ex_addr:1, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:33, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:46, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:56, Pred: http://localhost/hasAddress, Obj: Heidenkampsweg 99, 20097 Hamburg.
# Subj: ex_addr:81, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:4, Pred: http://localhost/hasAddress, Obj: ex_addr:4
# Subj: ex_comp:77, Pred: http://localhost/hasFNR, Obj: K1101R_HRB118781
# Subj: ex_addr:89, Pred: http://localhost/hasPLZ, Obj: 28755
# Subj: ex_comp:83, Pred: http://localhost/hasAddress, Obj: ex_addr:75
# Subj: ex_addr:85, Pred: http://localhost/hasAddress, Obj: Ostertorsteinweg 85, 28203 Bremen
# Subj: ex_comp:62, Pred: http://localhost/hasName, Obj: LuMa Projektentwicklungs-GmbH
# Subj: ex_comp:79, Pred: http://localhost/hasFNR, Obj: K1101R_HRB36153
# Subj: ex_comp:67, Pred: http://localhost/hasName, Obj: Verwaltungsgesellschaft MS "Barmbek" mbH
# Subj: ex_addr:63, Pred: http://localhost/hasPLZ, Obj: 20095
# Subj: ex_addr:84, Pred: http://localhost/hasAddress, Obj: Hartungstraße 12, 20146 Hamburg.
# Subj: ex_comp:80, Pred: http://localhost/hasAddress, Obj: ex_addr:72
# Subj: ex_addr:16, Pred: http://localhost/hasAddress, Obj: Königsallee 106, 40215 Düsseldorf.
# Subj: ex_comp:76, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:61, Pred: http://localhost/hasFNR, Obj: R1101_HRB36441
# Subj: ex_addr:21, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:63, Pred: http://localhost/hasFNR, Obj: H1101_H1101_HRA24477
# Subj: ex_comp:82, Pred: http://localhost/hasFNR, Obj: R1101_HRB70961
# Subj: ex_comp:14, Pred: http://localhost/hasName, Obj: Palletways Deutschland GmbH
# Subj: ex_comp:99, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:79, Pred: http://localhost/hasAddress, Obj: ex_addr:71
# Subj: ex_comp:55, Pred: http://localhost/hasAddress, Obj: ex_addr:52
# Subj: ex_comp:76, Pred: http://localhost/hasFNR, Obj: K1101R_HRB134994
# Subj: ex_comp:95, Pred: http://localhost/hasName, Obj: ES Medien Agentur + Handelsgesellschaft mbH & Co. KG
# Subj: ex_comp:86, Pred: http://localhost/hasAddress, Obj: ex_addr:78
# Subj: ex_comp:48, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:40, Pred: http://localhost/hasAddress, Obj: ex_addr:38
# Subj: ex_addr:74, Pred: http://localhost/hasAddress, Obj: Dominikanerstraße 24, 40545 Düsseldorf.
# Subj: ex_comp:75, Pred: http://localhost/hasAddress, Obj: ex_addr:68
# Subj: ex_comp:85, Pred: http://localhost/hasName, Obj: Luzemann Services Verwaltungsgesellschaft mbH
# Subj: ex_addr:78, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:31, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:29, Pred: http://localhost/hasFNR, Obj: K1101R_HRB95200
# Subj: ex_addr:64, Pred: http://localhost/hasAddress, Obj: Neuer Wall 55, c/o Matzen & Partner, 20354 Hamburg.
# Subj: ex_comp:99, Pred: http://localhost/hasFNR, Obj: H1101_H1101_HRB19715
# Subj: ex_addr:24, Pred: http://localhost/hasStreet, Obj: Gustav-Mahler-Platz 1
# Subj: ex_addr:7, Pred: http://localhost/hasAddress, Obj: Königstraße 28, 22767 Hamburg.
# Subj: ex_comp:24, Pred: http://localhost/hasAddress, Obj: ex_addr:22
# Subj: ex_comp:4, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:1, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:84, Pred: http://localhost/hasFNR, Obj: K1101R_HRB138995
# Subj: ex_comp:92, Pred: http://localhost/hasAddress, Obj: ex_addr:82
# Subj: ex_addr:23, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:51, Pred: http://localhost/hasStreet, Obj: Orleansstr.
# Subj: ex_addr:80, Pred: http://localhost/hasAddress, Obj: Am Stein 46, 22337 Hamburg.
# Subj: ex_addr:18, Pred: http://localhost/hasCity, Obj: Wuppertal.
# Subj: ex_addr:68, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_addr:9, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:25, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:54, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:50, Pred: http://localhost/hasStreet, Obj: Neumühlen 9
# Subj: ex_comp:49, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:83, Pred: http://localhost/hasName, Obj: Sell Facility Services GmbH
# Subj: ex_addr:14, Pred: http://localhost/hasPLZ, Obj: 40472
# Subj: ex_addr:63, Pred: http://localhost/hasStreet, Obj: Domstraße 19
# Subj: ex_addr:8, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:4, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:47, Pred: http://localhost/hasAddress, Obj: Katharinenstr.
# Subj: ex_addr:11, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_comp:41, Pred: http://localhost/hasFNR, Obj: K1101R_HRB32784
# Subj: ex_comp:67, Pred: http://localhost/hasFNR, Obj: K1101R_HRB88602
# Subj: ex_comp:7, Pred: http://localhost/hasName, Obj: Verwaltung IFÖ Zweite Immobilienfonds für Österreich GmbH
# Subj: ex_addr:46, Pred: http://localhost/hasPLZ, Obj: 20095
# Subj: ex_addr:7, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:70, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:43, Pred: http://localhost/hasFNR, Obj: K1101R_HRB79100
# Subj: ex_addr:87, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_comp:51, Pred: http://localhost/hasFNR, Obj: R1101_HRB58874
# Subj: ex_comp:30, Pred: http://localhost/hasName, Obj: Dura Automotive Systems GmbH
# Subj: ex_comp:20, Pred: http://localhost/hasName, Obj: Ferox Zweite Holding GmbH
# Subj: ex_addr:73, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:53, Pred: http://localhost/hasFNR, Obj: K1101R_HRB97760
# Subj: ex_addr:42, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:30, Pred: http://localhost/hasAddress, Obj: ex_addr:28
# Subj: ex_addr:67, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:73, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:18, Pred: http://localhost/hasFNR, Obj: R1101_HRB47559
# Subj: ex_addr:68, Pred: http://localhost/hasPLZ, Obj: 40211
# Subj: ex_comp:87, Pred: http://localhost/hasFNR, Obj: R1101_HRB27849
# Subj: ex_addr:29, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:42, Pred: http://localhost/hasAddress, Obj: Spielbudenplatz 27-28, 20359 Hamburg.
# Subj: ex_addr:90, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:16, Pred: http://localhost/hasAddress, Obj: ex_addr:14
# Subj: ex_addr:65, Pred: http://localhost/hasStreet, Obj: Löpelborg 8
# Subj: ex_addr:38, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:35, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:91, Pred: http://localhost/hasFNR, Obj: H1101_H1101_HRB30009
# Subj: ex_addr:29, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:21, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:35, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:90, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:5, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:35, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:57, Pred: http://localhost/hasName, Obj: SMK Verwertungsgesellschaft mbH
# Subj: ex_comp:28, Pred: http://localhost/hasFNR, Obj: K1101R_HRB91642
# Subj: ex_addr:4, Pred: http://localhost/hasPLZ, Obj: 40721
# Subj: ex_comp:43, Pred: http://localhost/hasName, Obj: LUISE Verwaltungs GmbH
# Subj: ex_addr:53, Pred: http://localhost/hasPLZ, Obj: 40210
# Subj: ex_comp:66, Pred: http://localhost/hasName, Obj: AL Aman Engineering and Trading UG (haftungsbeschränkt)
# Subj: ex_addr:71, Pred: http://localhost/hasAddress, Obj: Saseler Bogen 3, 22393 Hamburg.
# Subj: ex_comp:71, Pred: http://localhost/hasName, Obj: Merica Capital GmbH
# Subj: ex_comp:70, Pred: http://localhost/hasFNR, Obj: K1101R_HRB88029
# Subj: ex_addr:88, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:8, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:1, Pred: http://localhost/hasAddress, Obj: ex_addr:1
# Subj: ex_addr:61, Pred: http://localhost/hasStreet, Obj: Bremer Straße 103a
# Subj: ex_comp:98, Pred: http://localhost/hasAddress, Obj: ex_addr:88
# Subj: ex_comp:71, Pred: http://localhost/hasFNR, Obj: K1101R_HRB106743
# Subj: ex_comp:75, Pred: http://localhost/hasName, Obj: TT Trading GmbH
# Subj: ex_comp:46, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:62, Pred: http://localhost/hasFNR, Obj: H1101_H1101_HRB33484
# Subj: ex_addr:71, Pred: http://localhost/hasPLZ, Obj: 22393
# Subj: ex_comp:56, Pred: http://localhost/hasAddress, Obj: ex_addr:53
# Subj: ex_comp:72, Pred: http://localhost/hasName, Obj: Kröger Baugeräte Service GmbH
# Subj: ex_addr:20, Pred: http://localhost/hasStreet, Obj: Cremon 3
# Subj: ex_comp:19, Pred: http://localhost/hasFNR, Obj: K1101R_HRB67520
# Subj: ex_addr:32, Pred: http://localhost/hasPLZ, Obj: 22765
# Subj: ex_addr:50, Pred: http://localhost/hasPLZ, Obj: 22763
# Subj: ex_comp:13, Pred: http://localhost/hasName, Obj: wpd Windparks Westfalen IV GmbH
# Subj: ex_comp:5, Pred: http://localhost/hasName, Obj: ITERGO Informationstechnologie GmbH
# Subj: ex_addr:20, Pred: http://localhost/hasPLZ, Obj: 20457
# Subj: ex_comp:6, Pred: http://localhost/hasName, Obj: Rheinbahn AG
# Subj: ex_addr:42, Pred: rdf:type, Obj: ex:Address
# Subj: ex_addr:66, Pred: http://localhost/hasAddress, Obj: Neustraße 45, 40721 Hilden.
# Subj: ex_addr:86, Pred: http://localhost/hasAddress, Obj: Borner Stieg 32, 22417 Hamburg.
# Subj: ex_comp:13, Pred: http://localhost/hasFNR, Obj: H1101_H1101_HRB33397
# Subj: ex_comp:85, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:49, Pred: http://localhost/hasStreet, Obj: Derendorfer Allee 4
# Subj: ex_addr:10, Pred: http://localhost/hasStreet, Obj: Große Elbstraße 38
# Subj: ex_comp:93, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:81, Pred: http://localhost/hasAddress, Obj: Contrescarpe 8 c, 28203 Bremen
# Subj: ex_comp:28, Pred: http://localhost/hasAddress, Obj: ex_addr:26
# Subj: ex_addr:5, Pred: http://localhost/hasPLZ, Obj: 40477
# Subj: ex_comp:32, Pred: http://localhost/hasFNR, Obj: K1101R_HRA121233
# Subj: ex_comp:96, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:92, Pred: http://localhost/hasName, Obj: Verwaltungsgesellschaft EGRIMA mbH
# Subj: ex_comp:91, Pred: http://localhost/hasName, Obj: R.F.L. Gewerbe Immobilien Verwaltungs GmbH
# Subj: ex_comp:80, Pred: http://localhost/hasFNR, Obj: R1101_HRB68329
# Subj: ex_comp:3, Pred: http://localhost/hasFNR, Obj: H1101_H1101_HRB18423
# Subj: ex_comp:87, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:40, Pred: http://localhost/hasStreet, Obj: Schulterblatt 58
# Subj: ex_comp:45, Pred: http://localhost/hasName, Obj: Verwaltung Schiffahrts-Gesellschaft "HANSA BRANDENBURG" mbH
# Subj: ex_addr:83, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_addr:44, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:55, Pred: http://localhost/hasAddress, Obj: Unnastr.
# Subj: ex_addr:43, Pred: http://localhost/hasPLZ, Obj: 22763
# Subj: ex_addr:88, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:54, Pred: http://localhost/hasFNR, Obj: H1101_H1101_HRB19233
# Subj: ex_addr:61, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_addr:22, Pred: http://localhost/hasCity, Obj: Hamburg.
# Subj: ex_comp:87, Pred: http://localhost/hasName, Obj: Molten Europe GmbH
# Subj: ex_addr:23, Pred: http://localhost/hasStreet, Obj: Mönckebergstraße 13
# Subj: ex_addr:60, Pred: http://localhost/hasStreet, Obj: Mattentwiete 1
# Subj: ex_addr:31, Pred: http://localhost/hasPLZ, Obj: 20354
# Subj: ex_addr:5, Pred: http://localhost/hasCity, Obj: Düsseldorf.
# Subj: ex_addr:26, Pred: rdf:type, Obj: ex:Address
# Subj: ex_comp:8, Pred: http://localhost/hasFNR, Obj: K1101R_HRB29079
# Subj: ex_addr:57, Pred: http://localhost/hasAddress, Obj: Tiefer 15, 28195 Bremen
# Subj: ex_comp:15, Pred: http://localhost/hasFNR, Obj: K1101R_HRB98815
# Subj: ex_addr:69, Pred: http://localhost/hasAddress, Obj: Harderweg 1, 22549 Hamburg.
# Subj: ex_comp:95, Pred: rdf:type, Obj: ex:Company
# Subj: ex_comp:91, Pred: rdf:type, Obj: ex:Company
# Subj: ex_addr:58, Pred: rdf:type, Obj: ex:Address

# %% [markdown]
# ## Insert RDF Data

# %%
from rdflib import Graph, URIRef, Literal
from rdflib.namespace import RDF
from gremlin_python.driver import client
from gremlin_python.driver import serializer

import logging
import nest_asyncio
nest_asyncio.apply() #Needed to fix 'Running Event loop Issue' in Jupyter notebooks - This is not needed when executed as python script

logging.basicConfig(
    level=logging.DEBUG, 
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='RDF_DataIngestion.log',
    filemode='w'
)
logger = logging.getLogger(__name__)

def sanitize_key(key: str) -> str:
    return key.replace(' ', '_').split('/')[-1]

def process_rdf(rdf_path: str, gremlin_client: client.Client):
    rdf_graph = Graph()
    rdf_graph.parse(rdf_path, format="turtle")
    
    stats = {
        'vertices_processed': 0,
        'edges_created': 0,
        'properties_set': 0,
        'errors': 0
    }


    # Iteratively walking through all triplets
    for subj, pred, obj in rdf_graph:
        subj_uri = str(subj) 
        pred_name = sanitize_key(str(pred)) #Just some cleaninig of they key! :) 
        obj_value = str(obj) if isinstance(obj, Literal) else obj

    for subj, pred, obj in rdf_graph:
        try:
            subj_uri = str(subj)
            pred_name = sanitize_key(str(pred))
            obj_value = obj

            # Vertex creation/check
            '''
            Gremlin Patterns: 
            - Check existence with .fold()
            - Create if missing using coalesce()
            '''
            vertex_result = gremlin_client.submit(
                f"g.V().has('uri', '{subj_uri}').fold()"
                f".coalesce(__.unfold(), __.addV('{str(subj)}').property('uri', '{subj_uri}'))"
            ).all().result()


            
            if 'created' in str(vertex_result):
                stats['vertices_processed'] += 1
                logger.debug(f"Created new vertex: {subj_uri}")
            else:
                logger.debug(f"Existing vertex found: {subj_uri}")

            
            # Setting URI as UUID 
            if pred == RDF.type:
                # Handle type
                gremlin_client.submit(
                    f"g.V().has('uri', '{subj_uri}').property('rdf_type', '{str(obj)}')"
                ).all().result()
                logger.debug(f"Set rdf_type for {subj_uri}: {str(obj)}")
                stats['properties_set'] += 1

            elif isinstance(obj, URIRef):

                # Edge creation
                obj_uri = str(obj)

                '''
                If vertex with uri=obj_uri exists → Returns it

                If missing → Creates new vertex with:
                    Label: Entity (hardcoded default)
                    Property: uri = obj_uri

                '''



                # Checking if the Target Vertex already exists and adds it, in case it does not exist
                gremlin_client.submit(
                    f"g.V().has('uri', '{obj_uri}').fold()"
                    f".coalesce(__.unfold(), __.addV('Entity').property('uri', '{obj_uri}'))"
                ).all().result()

            
                edge_result = gremlin_client.submit(
                    f"""
                    g.V().has('uri', '{subj_uri}')
                    .addE('{pred_name}')
                    .to(__.V().has('uri', '{obj_uri}'))
                    """
                ).all().result()

                stats['edges_created'] += 1
                logger.info(f"Created edge: {subj_uri} -[{pred_name}]-> {obj_uri}")

            else:
                # Property handling
                if isinstance(obj, Literal):
                    value = obj.toPython()
                    if isinstance(value, str):
                        value = f"'{value.replace("'", "''")}'"
                    
                    prop_result = gremlin_client.submit(
                        f"g.V().has('uri', '{subj_uri}')"
                        f".property('{pred_name}', {value})"
                    ).all().result()
                    
                    stats['properties_set'] += 1
                    logger.debug(f"Set property {pred_name}={value} on {subj_uri}")

        except Exception as e:
            stats['errors'] += 1
            logger.error(f"Failed to process {subj} {pred} {obj}: {str(e)}", exc_info=True)

    # Summary logging
    logger.info("\nImport Statistics:")
    logger.info(f"Total vertices processed: {stats['vertices_processed']}")
    logger.info(f"Total edges created: {stats['edges_created']}")
    logger.info(f"Total properties set: {stats['properties_set']}")
    logger.info(f"Total errors encountered: {stats['errors']}")

# Initialize and run
gremlin_client = client.Client(
    url='ws://localhost:8182/gremlin',
    traversal_source='g',
    message_serializer=serializer.GraphSONSerializersV3d0())
process_rdf("data/testdataset.rdf", gremlin_client)
gremlin_client.close()

# %% [markdown]
# ## Remove Entity Nodes
# Those nodes are just a byproduct of a suboptimal population and are, due to timeconstraints only removed in this following way

# %%
from gremlin_python.driver.driver_remote_connection import DriverRemoteConnection
from janusgraph_python.driver.serializer import JanusGraphSONSerializersV3d0  # Correct import for JanusGraph serializer
from gremlin_python.process.anonymous_traversal import traversal


def delete_entities_by_uri(target_uri):
    # Establish connection
    connection = DriverRemoteConnection(
        'ws://localhost:8182/gremlin',
        'g',
        message_serializer=JanusGraphSONSerializersV3d0()
    )
    g = traversal().withRemote(connection)

    try:
        # Execute deletion query
        delete_result = g.V().has('uri', target_uri).drop().iterate()
        
        # Get deletion count (JanusGraph doesn't return counts natively)
        remaining = g.V().has('uri', target_uri).count().next()
        
        print(f"Deleted all entities with URI '{target_uri}'")
        print(f"Remaining entities with this URI: {remaining}")
        
    except Exception as e:
        print(f"Deletion failed: {str(e)}")
    finally:
        connection.close()

# Usage
delete_entities_by_uri('ex:Company')
delete_entities_by_uri('ex:Address')
# Out:
# Deleted all entities with URI 'ex:Company'
# Remaining entities with this URI: 0
# Deleted all entities with URI 'ex:Address'
# Remaining entities with this URI: 0

# %% [markdown]
# ## Create artifical ownership structures

# %%
from gremlin_python.driver.driver_remote_connection import DriverRemoteConnection
from gremlin_python.process.anonymous_traversal import traversal
from gremlin_python.process.graph_traversal import __  # Correct import for anonymous traversals
from janusgraph_python.driver.serializer import JanusGraphSONSerializersV3d0
import random
import traceback

# Connect to JanusGraph
connection = DriverRemoteConnection(
    'ws://localhost:8182/gremlin',
    'g',
    message_serializer=JanusGraphSONSerializersV3d0()
)
g = traversal().withRemote(connection)

# Helper functions to safely access label and id
def get_label(v):
    try:
        return v.label
    except AttributeError:
        return v.get("label")

def get_id(v):
    try:
        return v.id
    except AttributeError:
        return v.get("id")

# 1. Get all vertices and filter for labels containing "ex_comp"
all_vertices = g.V().toList()
filtered_vertices = [v for v in all_vertices if "ex_comp" in get_label(v)]

print(f"Found {len(filtered_vertices)} vertices with labels containing 'ex_comp'")

# 2. Select 50% randomly
if len(filtered_vertices) < 2:
    print("Not enough vertices to create edges.")
    connection.close()
    exit()

selected_vertices = random.sample(filtered_vertices, len(filtered_vertices) // 2)
print(f"Selected {len(selected_vertices)} vertices for edge creation")

# 3. Initialize incoming capacity to 1.0 per vertex
capacity = {get_id(v): 1.0 for v in selected_vertices}

# 4. Create edges between selected vertices with random weights
for source in selected_vertices:
    source_id = get_id(source)

    possible_targets = [v for v in selected_vertices if get_id(v) != source_id]
    random.shuffle(possible_targets)

    for target in possible_targets:
        target_id = get_id(target)

        if capacity[target_id] <= 0:
            continue  # Skip if no capacity left

        max_weight = min(1.0, capacity[target_id])
        weight = round(random.uniform(0.1, max_weight), 2)

        try:
            g.V(source_id).addE('weighted_connection').to(
                __.V(target_id)  # ✅ Proper anonymous traversal
            ).property('weight', weight).next()

            capacity[target_id] = max(0, capacity[target_id] - weight)

            print(f"Created edge {source_id} -> {target_id} with weight {weight} "
                  f"(Remaining capacity: {capacity[target_id]:.2f})")

        except Exception as e:
            print(f"Error creating edge {source_id} -> {target_id}: {e}")
            traceback.print_exc()

# Close connection
connection.close()
# Out:
# Found 100 vertices with labels containing 'ex_comp'
# Selected 50 vertices for edge creation
# Created edge 553064 -> 1327304 with weight 0.15 (Remaining capacity: 0.85)
# Created edge 553064 -> 520304 with weight 0.59 (Remaining capacity: 0.41)
# Created edge 553064 -> 1138888 with weight 0.4 (Remaining capacity: 0.60)
# Created edge 553064 -> 614432 with weight 0.13 (Remaining capacity: 0.87)
# Created edge 553064 -> 1298568 with weight 0.43 (Remaining capacity: 0.57)
# Created edge 553064 -> 647312 with weight 0.13 (Remaining capacity: 0.87)
# Created edge 553064 -> 659600 with weight 0.39 (Remaining capacity: 0.61)
# Created edge 553064 -> 1183944 with weight 0.69 (Remaining capacity: 0.31)
# Created edge 553064 -> 622624 with weight 0.14 (Remaining capacity: 0.86)
# Created edge 553064 -> 1347720 with weight 0.61 (Remaining capacity: 0.39)
# Created edge 553064 -> 663672 with weight 0.74 (Remaining capacity: 0.26)
# Created edge 553064 -> 557088 with weight 0.93 (Remaining capacity: 0.07)
# Created edge 553064 -> 1179848 with weight 0.25 (Remaining capacity: 0.75)
# Created edge 553064 -> 585840 with weight 0.98 (Remaining capacity: 0.02)
# Created edge 553064 -> 573472 with weight 1.0 (Remaining capacity: 0.00)
# Created edge 553064 -> 1290440 with weight 0.59 (Remaining capacity: 0.41)
# Created edge 553064 -> 1323208 with weight 0.28 (Remaining capacity: 0.72)
# Created edge 553064 -> 573552 with weight 0.66 (Remaining capacity: 0.34)
# Created edge 553064 -> 528496 with weight 0.37 (Remaining capacity: 0.63)
# Created edge 553064 -> 1163464 with weight 0.21 (Remaining capacity: 0.79)
# Created edge 553064 -> 589936 with weight 0.11 (Remaining capacity: 0.89)
# Created edge 553064 -> 577744 with weight 0.26 (Remaining capacity: 0.74)
# Created edge 553064 -> 577648 with weight 0.92 (Remaining capacity: 0.08)
# Created edge 553064 -> 614608 with weight 0.26 (Remaining capacity: 0.74)
# Created edge 553064 -> 667768 with weight 0.79 (Remaining capacity: 0.21)
# Created edge 553064 -> 573648 with weight 0.88 (Remaining capacity: 0.12)
# Created edge 553064 -> 610512 with weight 0.12 (Remaining capacity: 0.88)
# Created edge 553064 -> 1314952 with weight 0.3 (Remaining capacity: 0.70)
# Created edge 553064 -> 598136 with weight 0.32 (Remaining capacity: 0.68)
# Created edge 553064 -> 548968 with weight 0.33 (Remaining capacity: 0.67)
# Created edge 553064 -> 630928 with weight 0.89 (Remaining capacity: 0.11)
# Created edge 553064 -> 532592 with weight 0.26 (Remaining capacity: 0.74)
# Created edge 553064 -> 581840 with weight 0.89 (Remaining capacity: 0.11)
# Created edge 553064 -> 1323144 with weight 0.86 (Remaining capacity: 0.14)
# Created edge 553064 -> 1233096 with weight 0.49 (Remaining capacity: 0.51)
# Created edge 553064 -> 651408 with weight 0.28 (Remaining capacity: 0.72)
# Created edge 553064 -> 614520 with weight 0.23 (Remaining capacity: 0.77)
# Created edge 553064 -> 598048 with weight 0.72 (Remaining capacity: 0.28)
# Created edge 553064 -> 1245320 with weight 0.81 (Remaining capacity: 0.19)
# Created edge 553064 -> 1204424 with weight 0.34 (Remaining capacity: 0.66)
# Created edge 553064 -> 655504 with weight 0.5 (Remaining capacity: 0.50)
# Created edge 553064 -> 622712 with weight 0.17 (Remaining capacity: 0.83)
# Created edge 553064 -> 1265864 with weight 0.88 (Remaining capacity: 0.12)
# Created edge 553064 -> 647288 with weight 0.67 (Remaining capacity: 0.33)
# Created edge 553064 -> 1196232 with weight 0.14 (Remaining capacity: 0.86)
# Created edge 553064 -> 1339592 with weight 0.86 (Remaining capacity: 0.14)
# Created edge 553064 -> 606416 with weight 0.67 (Remaining capacity: 0.33)
# Created edge 553064 -> 635088 with weight 0.29 (Remaining capacity: 0.71)
# Created edge 553064 -> 569448 with weight 0.58 (Remaining capacity: 0.42)
# Created edge 1196232 -> 573552 with weight 0.16 (Remaining capacity: 0.18)
# Created edge 1196232 -> 577744 with weight 0.55 (Remaining capacity: 0.19)
# Created edge 1196232 -> 655504 with weight 0.49 (Remaining capacity: 0.01)
# Created edge 1196232 -> 557088 with weight 0.09 (Remaining capacity: 0.00)
# Created edge 1196232 -> 667768 with weight 0.18 (Remaining capacity: 0.03)
# Created edge 1196232 -> 614432 with weight 0.72 (Remaining capacity: 0.15)
# Created edge 1196232 -> 1314952 with weight 0.57 (Remaining capacity: 0.13)
# Created edge 1196232 -> 1163464 with weight 0.15 (Remaining capacity: 0.64)
# Created edge 1196232 -> 614608 with weight 0.55 (Remaining capacity: 0.19)
# Created edge 1196232 -> 598136 with weight 0.14 (Remaining capacity: 0.54)
# Created edge 1196232 -> 651408 with weight 0.53 (Remaining capacity: 0.19)
# Created edge 1196232 -> 1265864 with weight 0.11 (Remaining capacity: 0.01)
# Created edge 1196232 -> 1179848 with weight 0.24 (Remaining capacity: 0.51)
# Created edge 1196232 -> 573648 with weight 0.11 (Remaining capacity: 0.01)
# Created edge 1196232 -> 1339592 with weight 0.12 (Remaining capacity: 0.02)
# Created edge 1196232 -> 520304 with weight 0.22 (Remaining capacity: 0.19)
# Created edge 1196232 -> 1327304 with weight 0.81 (Remaining capacity: 0.04)
# Created edge 1196232 -> 1290440 with weight 0.17 (Remaining capacity: 0.24)
# Created edge 1196232 -> 1245320 with weight 0.15 (Remaining capacity: 0.04)
# Created edge 1196232 -> 630928 with weight 0.1 (Remaining capacity: 0.01)
# Created edge 1196232 -> 1347720 with weight 0.31 (Remaining capacity: 0.08)
# Created edge 1196232 -> 585840 with weight 0.02 (Remaining capacity: 0.00)
# Created edge 1196232 -> 647288 with weight 0.23 (Remaining capacity: 0.10)
# Created edge 1196232 -> 659600 with weight 0.19 (Remaining capacity: 0.42)
# Created edge 1196232 -> 569448 with weight 0.38 (Remaining capacity: 0.04)
# Created edge 1196232 -> 1138888 with weight 0.57 (Remaining capacity: 0.03)
# Created edge 1196232 -> 598048 with weight 0.12 (Remaining capacity: 0.16)
# Created edge 1196232 -> 1323208 with weight 0.56 (Remaining capacity: 0.16)
# Created edge 1196232 -> 1323144 with weight 0.13 (Remaining capacity: 0.01)
# Created edge 1196232 -> 589936 with weight 0.57 (Remaining capacity: 0.32)
# Created edge 1196232 -> 610512 with weight 0.85 (Remaining capacity: 0.03)
# Created edge 1196232 -> 577648 with weight 0.09 (Remaining capacity: 0.00)
# Created edge 1196232 -> 647312 with weight 0.76 (Remaining capacity: 0.11)
# Created edge 1196232 -> 1183944 with weight 0.13 (Remaining capacity: 0.18)
# Created edge 1196232 -> 532592 with weight 0.35 (Remaining capacity: 0.39)
# Created edge 1196232 -> 528496 with weight 0.62 (Remaining capacity: 0.01)
# Created edge 1196232 -> 553064 with weight 0.56 (Remaining capacity: 0.44)
# Created edge 1196232 -> 1204424 with weight 0.58 (Remaining capacity: 0.08)
# Created edge 1196232 -> 614520 with weight 0.11 (Remaining capacity: 0.66)
# Created edge 1196232 -> 663672 with weight 0.15 (Remaining capacity: 0.11)
# Created edge 1196232 -> 548968 with weight 0.47 (Remaining capacity: 0.20)
# Created edge 1196232 -> 1233096 with weight 0.17 (Remaining capacity: 0.34)
# Created edge 1196232 -> 581840 with weight 0.1 (Remaining capacity: 0.01)
# Created edge 1196232 -> 622712 with weight 0.16 (Remaining capacity: 0.67)
# Created edge 1196232 -> 635088 with weight 0.32 (Remaining capacity: 0.39)
# Created edge 1196232 -> 606416 with weight 0.28 (Remaining capacity: 0.05)
# Created edge 1196232 -> 622624 with weight 0.23 (Remaining capacity: 0.63)
# Created edge 1196232 -> 1298568 with weight 0.22 (Remaining capacity: 0.35)
# Created edge 1314952 -> 647288 with weight 0.1 (Remaining capacity: 0.00)
# Created edge 1314952 -> 598048 with weight 0.11 (Remaining capacity: 0.05)
# Created edge 1314952 -> 598136 with weight 0.39 (Remaining capacity: 0.15)
# Created edge 1314952 -> 647312 with weight 0.11 (Remaining capacity: 0.00)
# Created edge 1314952 -> 532592 with weight 0.23 (Remaining capacity: 0.16)
# Created edge 1314952 -> 1290440 with weight 0.16 (Remaining capacity: 0.08)
# Created edge 1314952 -> 606416 with weight 0.08 (Remaining capacity: 0.00)
# Created edge 1314952 -> 1233096 with weight 0.11 (Remaining capacity: 0.23)
# Created edge 1314952 -> 553064 with weight 0.16 (Remaining capacity: 0.28)
# Created edge 1314952 -> 1265864 with weight 0.09 (Remaining capacity: 0.00)
# Created edge 1314952 -> 651408 with weight 0.17 (Remaining capacity: 0.02)
# Created edge 1314952 -> 610512 with weight 0.09 (Remaining capacity: 0.00)
# Created edge 1314952 -> 548968 with weight 0.17 (Remaining capacity: 0.03)
# Created edge 1314952 -> 1163464 with weight 0.34 (Remaining capacity: 0.30)
# Created edge 1314952 -> 1323208 with weight 0.13 (Remaining capacity: 0.03)
# Created edge 1314952 -> 1323144 with weight 0.06 (Remaining capacity: 0.00)
# Created edge 1314952 -> 1245320 with weight 0.07 (Remaining capacity: 0.00)
# Created edge 1314952 -> 1179848 with weight 0.32 (Remaining capacity: 0.19)
# Created edge 1314952 -> 614520 with weight 0.1 (Remaining capacity: 0.56)
# Created edge 1314952 -> 569448 with weight 0.05 (Remaining capacity: 0.00)
# Created edge 1314952 -> 1138888 with weight 0.08 (Remaining capacity: 0.00)
# Created edge 1314952 -> 659600 with weight 0.2 (Remaining capacity: 0.22)
# Created edge 1314952 -> 655504 with weight 0.04 (Remaining capacity: 0.00)
# Created edge 1314952 -> 667768 with weight 0.08 (Remaining capacity: 0.00)
# Created edge 1314952 -> 1339592 with weight 0.07 (Remaining capacity: 0.00)
# Created edge 1314952 -> 663672 with weight 0.11 (Remaining capacity: 0.00)
# Created edge 1314952 -> 589936 with weight 0.12 (Remaining capacity: 0.20)
# Created edge 1314952 -> 622624 with weight 0.39 (Remaining capacity: 0.24)
# Created edge 1314952 -> 573552 with weight 0.14 (Remaining capacity: 0.04)
# Created edge 1314952 -> 1298568 with weight 0.29 (Remaining capacity: 0.06)
# Created edge 1314952 -> 577744 with weight 0.18 (Remaining capacity: 0.01)
# Created edge 1314952 -> 1196232 with weight 0.24 (Remaining capacity: 0.62)
# Created edge 1314952 -> 528496 with weight 0.04 (Remaining capacity: 0.00)
# Created edge 1314952 -> 614432 with weight 0.11 (Remaining capacity: 0.04)
# Created edge 1314952 -> 581840 with weight 0.07 (Remaining capacity: 0.00)
# Created edge 1314952 -> 1204424 with weight 0.1 (Remaining capacity: 0.00)
# Created edge 1314952 -> 622712 with weight 0.4 (Remaining capacity: 0.27)
# Created edge 1314952 -> 1347720 with weight 0.08 (Remaining capacity: 0.00)
# Created edge 1314952 -> 520304 with weight 0.11 (Remaining capacity: 0.08)
# Created edge 1314952 -> 630928 with weight 0.06 (Remaining capacity: 0.00)
# Created edge 1314952 -> 1327304 with weight 0.06 (Remaining capacity: 0.00)
# Created edge 1314952 -> 585840 with weight 0.06 (Remaining capacity: 0.00)
# Created edge 1314952 -> 573648 with weight 0.08 (Remaining capacity: 0.00)
# Created edge 1314952 -> 635088 with weight 0.28 (Remaining capacity: 0.11)
# Created edge 1314952 -> 1183944 with weight 0.15 (Remaining capacity: 0.03)
# Created edge 1314952 -> 614608 with weight 0.18 (Remaining capacity: 0.01)
# Created edge 589936 -> 598048 with weight 0.08 (Remaining capacity: 0.00)
# Created edge 589936 -> 614520 with weight 0.23 (Remaining capacity: 0.33)
# Created edge 589936 -> 520304 with weight 0.08 (Remaining capacity: 0.00)
# Created edge 589936 -> 663672 with weight 0.06 (Remaining capacity: 0.00)
# Created edge 589936 -> 1196232 with weight 0.1 (Remaining capacity: 0.52)
# Created edge 589936 -> 1233096 with weight 0.19 (Remaining capacity: 0.04)
# Created edge 589936 -> 1298568 with weight 0.09 (Remaining capacity: 0.00)
# Created edge 589936 -> 598136 with weight 0.14 (Remaining capacity: 0.01)
# Created edge 589936 -> 577744 with weight 0.09 (Remaining capacity: 0.00)
# Created edge 589936 -> 659600 with weight 0.2 (Remaining capacity: 0.02)
# Created edge 589936 -> 573552 with weight 0.09 (Remaining capacity: 0.00)
# Created edge 589936 -> 532592 with weight 0.15 (Remaining capacity: 0.01)
# Created edge 589936 -> 553064 with weight 0.24 (Remaining capacity: 0.04)
# Created edge 589936 -> 548968 with weight 0.1 (Remaining capacity: 0.00)
# Created edge 589936 -> 651408 with weight 0.07 (Remaining capacity: 0.00)
# Created edge 589936 -> 1183944 with weight 0.03 (Remaining capacity: 0.00)
# Created edge 589936 -> 1347720 with weight 0.05 (Remaining capacity: 0.00)
# Created edge 589936 -> 1290440 with weight 0.08 (Remaining capacity: 0.00)
# Created edge 589936 -> 1163464 with weight 0.25 (Remaining capacity: 0.05)
# Created edge 589936 -> 614608 with weight 0.02 (Remaining capacity: 0.00)
# Created edge 589936 -> 622624 with weight 0.15 (Remaining capacity: 0.09)
# Created edge 589936 -> 614432 with weight 0.08 (Remaining capacity: 0.00)
# Created edge 589936 -> 1179848 with weight 0.12 (Remaining capacity: 0.07)
# Created edge 589936 -> 622712 with weight 0.21 (Remaining capacity: 0.06)
# Created edge 589936 -> 635088 with weight 0.1 (Remaining capacity: 0.01)
# Created edge 589936 -> 1323208 with weight 0.06 (Remaining capacity: 0.00)
# Created edge 589936 -> 1314952 with weight 0.11 (Remaining capacity: 0.02)
# Created edge 651408 -> 1163464 with weight 0.09 (Remaining capacity: 0.00)
# Created edge 651408 -> 635088 with weight 0.02 (Remaining capacity: 0.00)
# Created edge 651408 -> 598136 with weight 0.02 (Remaining capacity: 0.00)
# Created edge 651408 -> 659600 with weight 0.06 (Remaining capacity: 0.00)
# Created edge 651408 -> 1183944 with weight 0.07 (Remaining capacity: 0.00)
# Created edge 651408 -> 1233096 with weight 0.06 (Remaining capacity: 0.00)
# Created edge 651408 -> 520304 with weight 0.03 (Remaining capacity: 0.00)
# Created edge 651408 -> 1179848 with weight 0.09 (Remaining capacity: 0.00)
# Created edge 651408 -> 1290440 with weight 0.05 (Remaining capacity: 0.00)
# Created edge 651408 -> 532592 with weight 0.07 (Remaining capacity: 0.00)
# Created edge 651408 -> 622624 with weight 0.1 (Remaining capacity: 0.00)
# Created edge 651408 -> 553064 with weight 0.06 (Remaining capacity: 0.00)
# Created edge 651408 -> 1196232 with weight 0.41 (Remaining capacity: 0.11)
# Created edge 651408 -> 614520 with weight 0.18 (Remaining capacity: 0.15)
# Created edge 651408 -> 589936 with weight 0.2 (Remaining capacity: 0.00)
# Created edge 651408 -> 622712 with weight 0.08 (Remaining capacity: 0.00)
# Created edge 651408 -> 1314952 with weight 0.07 (Remaining capacity: 0.00)
# Created edge 663672 -> 1196232 with weight 0.11 (Remaining capacity: 0.00)
# Created edge 663672 -> 614520 with weight 0.11 (Remaining capacity: 0.04)
# Created edge 663672 -> 589936 with weight 0.06 (Remaining capacity: 0.00)
# Created edge 573472 -> 614520 with weight 0.07 (Remaining capacity: 0.00)
# Created edge 573472 -> 1196232 with weight 0.01 (Remaining capacity: 0.00)
